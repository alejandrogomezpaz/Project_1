# %% [markdown]
# Fixed: duplicates, missing customer IDs and product descriptions and 0$ sales.
# Added: revenue and return columns
# Anaylzed:
# 1. net revenue by country
# 2. net revenue growth (gross vs percentile)
# 3. Gross Year over Year growth (scalar)
# 4. Return Rate by Country
# 5. Revenue by price, revenue by quantity
# 6. Customer Cohort Analysis by revenue, price, and quantity
# 7. Custoemrs tend to buy only once
#
# Key Takeaways:
# 1. Seasonal business model
# 2. United Kingdom dominates revenue
# 3. 8% Year over Year Growth
# 4. Return rate is MUCH HIGHER in United Kingdom: concerning
# 5. Revenue Driven by small quantity, low price sales
# 6. Likewise, Customers are primarily one-time, low price low-quantity.

# %% [markdown]
# 1. net revenue by country

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. net revenue growth (gross vs percentile)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Gross Year over Year growth (scalar): *8.87%*

# %% [markdown]
# 4. Return Rate by Country (in percent)

# %% [markdown]
# Country
# United Kingdom          1.72
# Germany                 0.09
# France                  0.05
# EIRE                    0.04
# Channel Islands         0.02
# Spain                   0.01
# Japan                   0.01
# Portugal                0.01
# Netherlands             0.01
# United Arab Emirates    0.01

# %% [markdown]
# 5. Revenue by price, revenue by quantity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. Customer Cohort Analysis by revenue, price, and quantity

# %% [markdown]
# ![image.png](attachment:image.png)
